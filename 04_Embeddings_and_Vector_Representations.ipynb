# %% [markdown]
# # 🔢 Notebook 04: Embeddings and Vector Representations
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand what embeddings are
# 2. Use OpenAI Embeddings
# 3. Use Google Gemini Embeddings
# 4. Compare embedding models
# 5. Calculate similarity between vectors

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print("✅ Setup complete")
# Out:
# ✅ Setup complete

# %% [markdown]
# ## 1. What are Embeddings? 🤔
#
# ### 🔰 BEGINNER
#
# **Embeddings** convert text into numbers (vectors) that capture meaning.
#
# Think of it like a GPS coordinate:
# - "dog" → [0.2, 0.8, 0.1, ...] (1536 numbers)
# - "cat" → [0.3, 0.7, 0.2, ...] (close to "dog"!)
# - "car" → [0.9, 0.1, 0.8, ...] (far from "dog")
#
# Similar meanings = Similar vectors!

# %% [markdown]
# ## 2. OpenAI Embeddings

# %%
from langchain_openai import OpenAIEmbeddings

# Initialize
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# Create embedding for a query
query = "What is machine learning?"
query_vector = embeddings.embed_query(query)

print(f"Query: {query}")
print(f"Vector dimensions: {len(query_vector)}")
print(f"First 5 values: {query_vector[:5]}")

# Embed multiple documents
docs = [
    "Machine learning is a subset of AI",
    "Deep learning uses neural networks",
    "The weather is sunny today"
]

doc_vectors = embeddings.embed_documents(docs)
print(f"\nEmbedded {len(doc_vectors)} documents")
# Out:
# Query: What is machine learning?
# Vector dimensions: 1536
# First 5 values: [-0.002476818859577179, -0.012755980715155602, -0.006645360495895147, -0.03157883137464523, 0.028759293258190155]
#
# Embedded 3 documents

# %%
for doc, vector in zip(docs, doc_vectors):
    print("\n-----------------------------")
    print(f"Document Text: {doc}")
    print(f"Vector length: {len(vector)}")
    print(f"First 10 values: {vector[:10]}")
# Out:
# -----------------------------
# Document Text: Machine learning is a subset of AI
# Vector length: 1536
# First 10 values: [-0.02326645515859127, -0.056493259966373444, -0.009426760487258434, -0.02003607153892517, 0.05049397796392441, -0.009998807683587074, 0.017478683963418007, 0.04637908190488815, -0.02728520706295967, 0.02042064070701599]
#
# -----------------------------
# Document Text: Deep learning uses neural networks
# Vector length: 1536
# First 10 values: [-0.011690431274473667, -0.0526653416454792, 0.03811866417527199, -0.014323698356747627, 0.0373329296708107, -0.024166595190763474, -0.01396268606185913, 0.06939932703971863, -0.037778887897729874, 0.045827340334653854]
#
# -----------------------------
# Document Text: The weather is sunny today
# Vector length: 1536
# First 10 values: [0.01581730879843235, -0.03885713219642639, 0.007162327412515879, -0.009371213614940643, 0.035318098962306976, 0.019248003140091896, 0.021715695038437843, 0.006259513087570667, -0.010231896303594112, -0.03888120502233505]

# %% [markdown]
# ## 3. Google Gemini Embeddings

# %%
# !uv pip install langchain-google-genai
# Out:
# Audited 1 package in 35ms

# %%
# Google Gemini Embeddings
if os.getenv("GOOGLE_API_KEY"):
    from langchain_google_genai import GoogleGenerativeAIEmbeddings
    
    gemini_embeddings = GoogleGenerativeAIEmbeddings(
        model="models/embedding-001"
    )
    
    vector = gemini_embeddings.embed_query("Hello world")
    print(f"Gemini vector dimensions: {len(vector)}")
else:
    print("⚠️ Google API key not found. Set GOOGLE_API_KEY in .env")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:227, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     226 try:
# --> 227     result = self.client.batch_embed_contents(
#     228         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     229     )
#     230 except Exception as e:
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1392, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1391 # Send the request.
# -> 1392 response = rpc(
#    1393     request,
#    1394     retry=retry,
#    1395     timeout=timeout,
#    1396     metadata=metadata,
#    1397 )
#    1399 # Done; return the response.
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[6], line 9
#       3     from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       5     gemini_embeddings = GoogleGenerativeAIEmbeddings(
#       6         model="models/embedding-001"
#       7     )
# ----> 9     vector = gemini_embeddings.embed_query("Hello world")
#      10     print(f"Gemini vector dimensions: {len(vector)}")
#      11 else:
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:256, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     242 """Embed a text.
#     243
#     244 Args:
#    (...)    253     Embedding for the text.
#     254 """
#     255 task_type = self.task_type or "RETRIEVAL_QUERY"
# --> 256 return self.embed_documents(
#     257     [text],
#     258     task_type=task_type,
#     259     titles=[title] if title else None,
#     260     output_dimensionality=output_dimensionality,
#     261 )[0]
#
# File c:\UltimateRAG\simple-rag-langchain\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:231, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     227         result = self.client.batch_embed_contents(
#     228             BatchEmbedContentsRequest(requests=requests, model=self.model)
#     229         )
#     230     except Exception as e:
# --> 231         raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#     232     embeddings.extend([list(e.values) for e in result.embeddings])
#     233 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerDayPerUserPerProjectPerModel-FreeTier"
# }
# ]

# %% [markdown]
# ## 4. Similarity Calculation

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    """Calculate cosine similarity between two vectors"""
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Test similarity
texts = [
    "I love programming",
    "I enjoy coding",
     "The weather is nice"
    # "I love weather"
]

vectors = [embeddings.embed_query(text) for text in texts]

print("Similarity Scores:")
print(f"'{texts[0]}' vs '{texts[1]}': {cosine_similarity(vectors[0], vectors[1]):.4f}")
print(f"'{texts[0]}' vs '{texts[2]}': {cosine_similarity(vectors[0], vectors[2]):.4f}")
print("\nSimilar meanings = Higher similarity score!")
# Out:
# Similarity Scores:
# 'I love programming' vs 'I enjoy coding': 0.7529
# 'I love programming' vs 'The weather is nice': 0.2328
#
# Similar meanings = Higher similarity score!

# %% [markdown]
# ## Summary
#
# ✅ Embeddings convert text to vectors
# ✅ OpenAI text-embedding-3-small: 1536 dimensions
# ✅ Google Gemini: 768 dimensions
# ✅ Cosine similarity measures vector similarity
#
# **Next:** Vector Stores for efficient search!
